# %%
# Step 1: Clone the repository
from getpass import getpass
import os

# Remove existing directory if it exists
# !rm -rf /content/AdvDeepLearningHW1

# Securely get token (won't be visible in notebook output)
token = getpass('Enter your GitHub token: ')

# Clone with authentication - use variable substitution correctly
repo_url = f"https://{token}@github.com/ericarmstr0ng/AdvDeepLearningHW1.git"
# !git clone $repo_url /content/AdvDeepLearningHW1

# %cd /content/AdvDeepLearningHW1

# Configure git for pushing
# !git config user.name "ericarmstr0ng"
# !git config user.email "earmstrong81@gmail.com"
# Out:
# Cloning into '/content/AdvDeepLearningHW1'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 83 (delta 42), reused 33 (delta 15), pack-reused 22 (from 1)
# Receiving objects: 100% (83/83), 66.26 MiB | 15.98 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/AdvDeepLearningHW1

# %%
# !ls
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Exception ignored in atexit callback: <bound method InteractiveShell.atexit_operations of <google.colab._shell.Shell object at 0x795e3675bd10>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3924, in atexit_operations
#     self.reset(new_session=False)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 1445, in reset
#     self.history_manager.reset(new_session)
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_history.py", line 33, in reset
#     super(ColabHistoryManager, self).reset(new_session=new_session)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/history.py", line 592, in reset
#     self.dir_hist[:] = [os.getcwd()]
#                         ^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory

# %%
# %cd /content/AdvDeepLearningHW1
# !git log --oneline -10
# Out:
# /content/AdvDeepLearningHW1
# 13076ad (HEAD -> main, origin/main, origin/HEAD) SecondUpdate
# 0899e09 Updated qlora
# 086caf5 Fixed dtype error
# f90b31d Implement HalfLinear and update demo notebook
# d1c6467 Implement HalfLinear and update demo notebook
# 0e04523 Implement HalfLinear and update demo notebook
# 3b81ebd Implement HalfLinear and update demo notebook
# ac62832 Implement HalfLinear and update demo notebook
# a322e05 Implement HalfLinear and update demo notebook
# 8b45f07 Implement HalfLinear and update demo notebook

# %%
# !pip install -r requirements.txt

# %%
# Go back 1 commit
# %cd /content/AdvDeepLearningHW1
# !git checkout f90b31d
# Out:
# /content/AdvDeepLearningHW1
# Note: switching to 'f90b31d'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at f90b31d Implement HalfLinear and update demo notebook

# %%
# !python3 -m grader homework -v
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /usr/bin/python3: No module named grader
# Exception ignored in atexit callback: <bound method InteractiveShell.atexit_operations of <google.colab._shell.Shell object at 0x7a8e7b785af0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3924, in atexit_operations
#     self.reset(new_session=False)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 1445, in reset
#     self.history_manager.reset(new_session)
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_history.py", line 33, in reset
#     super(ColabHistoryManager, self).reset(new_session=new_session)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/history.py", line 592, in reset
#     self.dir_hist[:] = [os.getcwd()]
#                         ^^^^^^^^^^^
# ...

# %%
# !git add . && git status
# !git commit -m "Implement HalfLinear and update demo notebook homework1" && git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   ea34339.zip
# 	new file:   grader/__pycache__/__main__.cpython-312.pyc
# 	new file:   grader/__pycache__/grader.cpython-312.pyc
# 	new file:   grader/__pycache__/tests.cpython-312.pyc
# 	new file:   homework/__pycache__/__init__.cpython-312.pyc
# 	new file:   homework/__pycache__/bignet.cpython-312.pyc
# 	new file:   homework/__pycache__/compare.cpython-312.pyc
# 	new file:   homework/__pycache__/half_precision.cpython-312.pyc
# 	new file:   homework/__pycache__/lora.cpython-312.pyc
# 	new file:   homework/__pycache__/low_precision.cpython-312.pyc
# 	new file:   homework/__pycache__/lower_precision.cpython-312.pyc
# 	new file:   homework/__pycache__/qlora.cpython-312.pyc
# 	new file:   homework/__pycache__/stats.cpython-312.pyc
#
# [main 5ef3ccf] Implement HalfLinear and update demo notebook homework1
# ...

# %%
# %cd /content/AdvDeepLearningHW1
# !git pull
# Out:
# /content/AdvDeepLearningHW1
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 368 bytes | 368.00 KiB/s, done.
# From https://github.com/ericarmstr0ng/AdvDeepLearningHW1
#    2224ddc..91610d9  main       -> origin/main
# Updating 2224ddc..91610d9
# Fast-forward
#  homework/qlora.py | 2 ++
#  1 file changed, 2 insertions(+)

# %%
# Run the stats command
# !python3 -m homework.stats bignet
# Out:
# /usr/bin/python3: Error while finding module specification for 'homework.stats' (ModuleNotFoundError: No module named 'homework')

# %%
# !python3 -m homework.stats bignet half_precision
# !python3 -m homework.compare bignet half_precision

# %%
# !python3 -m homework.stats bignet qlora
# !python3 -m homework.compare bignet qlora
# Out:
#                          bignet         qlora
# Trainable params          18.90 M         0.60 M
# Non-trainable params       0.00 M        10.64 M
# Total params              18.90 M        11.24 M
# Theoretical memory        72.11 MB       13.61 MB
# Actual memory             72.11 MB       13.61 MB
# Forward memory             9.12 MB        0.00 MB
# Backward memory           80.23 MB        2.29 MB
# Comparing bignet and qlora
#  - Max difference: 0.1905
#  - Mean difference: 0.0307

# %%
# !python3 -m homework.stats bignet qlora
# !python3 -m homework.compare bignet qlora
# Out:
#                          bignet         qlora
# Trainable params          18.90 M         0.60 M
# Non-trainable params       0.00 M        10.64 M
# Total params              18.90 M        11.24 M
# Theoretical memory        72.11 MB       13.61 MB
# Actual memory             72.11 MB       13.61 MB
# Forward memory             9.12 MB        0.00 MB
# Backward memory           80.23 MB        2.29 MB
# Comparing bignet and qlora
#  - Max difference: 0.1819
#  - Mean difference: 0.0308

# %%
# !python3 -m homework.stats bignet qlora
# !python3 -m homework.compare bignet qlora
# Out:
#                          bignet         qlora
# Trainable params          18.90 M         1.19 M
# Non-trainable params       0.00 M        10.64 M
# Total params              18.90 M        11.83 M
# Theoretical memory        72.11 MB       15.86 MB
# Actual memory             72.11 MB       15.86 MB
# Forward memory             9.12 MB        0.00 MB
# Backward memory           80.23 MB        4.54 MB
# Comparing bignet and qlora
#  - Max difference: 0.1963
#  - Mean difference: 0.0308

# %%
# !python3 -m homework.stats bignet qlora
# !python3 -m homework.compare bignet qlora
# Out:
#                          bignet         qlora
# Trainable params          18.90 M         0.80 M
# Non-trainable params       0.00 M         7.09 M
# Total params              18.90 M         7.89 M
# Theoretical memory        72.11 MB       10.59 MB
# Actual memory             72.11 MB       10.59 MB
# Forward memory             9.12 MB        0.00 MB
# Backward memory           80.23 MB        3.04 MB
# Comparing bignet and qlora
#  - Max difference: 5.1394
#  - Mean difference: 0.9595

# %%
# !python3 -m grader homework -v
# Out:
# Val grader loaded.
# [INFO     00:00:002] LoRA
# [WARNING  00:00:850]   - Forward accuracy                                   [ 10 / 10  ]
# [WARNING  00:01:179]   - Memory and parameters                              [ 10 / 10  ]
# [WARNING  00:02:719]   - Backward accuracy                                  [ 10 / 10  ]
# [INFO     00:02:719]  --------------------------------------------------    [  30 /  30 ]
# [INFO     00:02:720] QLORA
# [WARNING  00:03:198]   - Forward accuracy                                   [ 10 / 10  ]
# [WARNING  00:03:516]   - Memory and parameters                              [ 10 / 10  ]
# [WARNING  00:04:347]   - Backward accuracy                                  [ 10 / 10  ]
# [INFO     00:04:347]  --------------------------------------------------    [  30 /  30 ]
# [INFO     00:04:350] Half Precision
# [WARNING  00:04:988]   - Forward accuracy                                   [ 10 / 10  ]
# ...

# %%
# Check if forward method exists
# %cd /content/AdvDeepLearningHW1
# !grep -n "def forward" homework/qlora.py
# Out:
# /content/AdvDeepLearningHW1
# 30:    def forward(self, x: torch.Tensor) -> torch.Tensor:
# 60:        def forward(self, x: torch.Tensor) -> torch.Tensor:
# 81:    def forward(self, x: torch.Tensor) -> torch.Tensor:

# %%
# !python3 bundle.py homework ea34339
# Out:
# bignet.py
# lower_precision.py
# qlora.py
# __init__.py
# fit.py
# oldqLora.py
# compare.py
# half_precision.py
# lora.py
# low_precision.py
# stats.py
# Submission created: /content/AdvDeepLearningHW1/ea34339.zip 0.01 MB

# %%
# !python3 bundle.py homework ea34339.zip
# Out:
# lower_precision.py
# lora.py
# bignet.py
# fit.py
# half_precision.py
# stats.py
# __init__.py
# compare.py
# qlora.py
# low_precision.py
# Submission created: /content/AdvDeepLearningHW1/ea34339.zip.zip 0.01 MB

# %%
from google.colab import files
files.download('/content/AdvDeepLearningHW1/ea34339.zip')

# %%
# Find the zip file
# !find /content -name "*.zip" 2>/dev/null
# !ls -la /content/AdvDeepLearningHW1/*.zip 2>/dev/null || echo "No zip in repo root"
# Out:
# /content/AdvDeepLearningHW1/ea34339.zip
# /content/AdvDeepLearningHW1/ea34339.zip.zip
# -rw-r--r-- 1 root root 9574 Feb  1 04:20 /content/AdvDeepLearningHW1/ea34339.zip
# -rw-r--r-- 1 root root 9574 Feb  1 04:21 /content/AdvDeepLearningHW1/ea34339.zip.zip

# %%
# Force fresh pull in Colab
# %cd /content/AdvDeepLearningHW1
# !git fetch origin
# !git reset --hard origin/main
# !python3 -m grader homework -v
# Out:
# /content/AdvDeepLearningHW1
# HEAD is now at 0899e09 Updated qlora
# Val grader loaded.
# [INFO     00:00:002] LoRA
# [WARNING  00:00:948]   - Forward accuracy                                   [ 10 / 10  ]
# [WARNING  00:01:251]   - Memory and parameters                              [ 10 / 10  ]
# [WARNING  00:02:779]   - Backward accuracy                                  [ 10 / 10  ]
# [INFO     00:02:779]  --------------------------------------------------    [  30 /  30 ]
# [INFO     00:02:780] QLORA
# [WARNING  00:03:077]   - Forward accuracy                                   [ 0 / 10 AttributeError ]
# [ERROR    00:03:077] Traceback (most recent call last):
# [ERROR    00:03:077]   File "/content/AdvDeepLearningHW1/grader/grader.py", line 64, in wrapper
# [ERROR    00:03:077]     v = func(self, **a)
# [ERROR    00:03:077]         ^^^^^^^^^^^^^^^
# [ERROR    00:03:077]   File "/content/AdvDeepLearningHW1/grader/tests.py", line 234, in test_forward_diff
# ...

# %%
# Verify the actual file content in Colab
# %cd /content/AdvDeepLearningHW1
# !echo "=== Checking QLoRALinear.forward ==="
# !sed -n '30,46p' homework/qlora.py
# !echo ""
# !echo "=== Checking QLoRABigNet.forward ==="
# !sed -n '81,82p' homework/qlora.py
# !echo ""
# !echo "=== Checking imports ==="
# !head -n 10 homework/qlora.py
# Out:
# /content/AdvDeepLearningHW1
# === Checking QLoRALinear.forward ===
#     def forward(self, x: torch.Tensor) -> torch.Tensor:
#         # TODO: Forward. Make sure to cast inputs to self.linear_dtype and the output back to x.dtype
#         original_datatype = x.dtype
#         x_compute = x.to(self.linear_dtype)
#
#         weight = block_dequantize_4bit(self.weight_q4, self.weight_norm)
#         weight = weight.view(self._shape)
#
#         frozen_base = torch.nn.functional.linear(x_compute, weight, self.bias)
#         frozen_base = frozen_base.to(original_datatype)
#         #lora forward ie a*b
#         lora_out = self.lora_b(self.lora_a(x))
#
#         # W + a*b
#         return frozen_base + lora_out
#         # raise NotImplementedError()
#
#
# === Checking QLoRABigNet.forward ===
#     def forward(self, x: torch.Tensor) -> torch.Tensor:
#         return self.model(x)
#
# === Checking imports ===
# from pathlib import Path
#
# import torch
#
# ...

# %%
# Clear Python cache
# %cd /content/AdvDeepLearningHW1
# !find . -type d -name __pycache__ -exec rm -rf {} + 2>/dev/null || true
# !find . -name "*.pyc" -delete 2>/dev/null || true
# !echo "Cache cleared"
# Out:
# /content/AdvDeepLearningHW1
# Cache cleared

# %%
# After restart, navigate to directory
# %cd /content/AdvDeepLearningHW1
# !pip install -q -r requirements.txt
# Out:
# /content/AdvDeepLearningHW1

# %%
# Run grader with fresh Python imports
# !python3 -m grader homework -v
# Out:
# Val grader loaded.
# [INFO     00:00:006] LoRA
# [WARNING  00:00:970]   - Forward accuracy                                   [ 10 / 10  ]
# [WARNING  00:01:280]   - Memory and parameters                              [ 10 / 10  ]
# [WARNING  00:02:843]   - Backward accuracy                                  [ 10 / 10  ]
# [INFO     00:02:843]  --------------------------------------------------    [  30 /  30 ]
# [INFO     00:02:844] QLORA
# [WARNING  00:03:212]   - Forward accuracy                                   [ 0 / 10 AttributeError ]
# [ERROR    00:03:212] Traceback (most recent call last):
# [ERROR    00:03:212]   File "/content/AdvDeepLearningHW1/grader/grader.py", line 64, in wrapper
# [ERROR    00:03:212]     v = func(self, **a)
# [ERROR    00:03:212]         ^^^^^^^^^^^^^^^
# [ERROR    00:03:212]   File "/content/AdvDeepLearningHW1/grader/tests.py", line 234, in test_forward_diff
# ...
